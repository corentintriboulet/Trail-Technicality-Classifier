# %%
import pandas as pd

# %%
import pandas as pd
from pandas import read_csv, read_json

# %%
# load data
raw_csv = read_csv('reunion_segments.csv')
df = pd.DataFrame(raw_csv)
df.head()

# %%
raw_json = read_json('reunion_segments.json')
df_json = pd.DataFrame(raw_json)
df_json.head()

# %%
raw_parquet = pd.read_parquet('reunion_segments.parquet')
df_parquet = pd.DataFrame(raw_parquet)
df_parquet.head()
